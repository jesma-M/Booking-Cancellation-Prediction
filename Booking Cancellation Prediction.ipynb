# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('booking.csv')

# %%
data
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
data.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
data.describe(include='O')
# Out:
#        Booking_ID type of meal    room type market segment type  \
# count       36285        36285        36285               36285
# unique      36285            4            7                   5
# top      INN00001  Meal Plan 1  Room_Type 1              Online
# freq            1        27842        28138               23221
#
#        date of reservation booking status
# count                36285          36285
# unique                 553              2
# top             10/13/2018   Not_Canceled
# freq                   254          24396

# %%
data.isnull().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
cat=[i for i in data.columns if data[i].dtypes=='O']

# %%
len(cat)
# Out:
# 6

# %%
data.columns
# Out:
# Index(['Booking_ID', 'number of adults', 'number of children',
#        'number of weekend nights', 'number of week nights', 'type of meal',
#        'car parking space', 'room type', 'lead time', 'market segment type',
#        'repeated', 'P-C', 'P-not-C', 'average price', 'special requests',
#        'date of reservation', 'booking status'],
#       dtype='object')

# %%
sns.scatterplot(data=data,x='type of meal',y='booking status',hue='average price',)
# Out:
# <Axes: xlabel='type of meal', ylabel='booking status'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=data['room type'],y=data['average price'],hue=data['booking status'])
# Out:
# <Axes: xlabel='room type', ylabel='average price'>

# %%
sns.boxplot(x=data['type of meal'],y=data['average price'])
# Out:
# <Axes: xlabel='type of meal', ylabel='average price'>

# %%
sns.boxplot(x=data['market segment type'],y=data['booking status'])
# Out:
# <Axes: xlabel='market segment type', ylabel='booking status'>

# %%
data[['type of meal']]
# Out:
#        type of meal
# 0       Meal Plan 1
# 1      Not Selected
# 2       Meal Plan 1
# 3       Meal Plan 1
# 4      Not Selected
# ...             ...
# 36280   Meal Plan 2
# 36281   Meal Plan 1
# 36282   Meal Plan 1
# 36283   Meal Plan 1
# 36284   Meal Plan 1
#
# [36285 rows x 1 columns]

# %%
for i in data[['booking status','market segment type','room type','type of meal','Booking_ID']]:
    print(data[i].unique()) 
    print("****"*8)
# Out:
# ['Not_Canceled' 'Canceled']
# ********************************
# ['Offline' 'Online' 'Corporate' 'Aviation' 'Complementary']
# ********************************
# ['Room_Type 1' 'Room_Type 4' 'Room_Type 2' 'Room_Type 6' 'Room_Type 5'
#  'Room_Type 7' 'Room_Type 3']
# ********************************
# ['Meal Plan 1' 'Not Selected' 'Meal Plan 2' 'Meal Plan 3']
# ********************************
# ['INN00001' 'INN00002' 'INN00003' ... 'INN36284' 'INN36285' 'INN36286']
# ********************************

# %%
data.drop('Booking_ID',axis=1,inplace=True)

# %%
data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price  \
# ...

# %%
data['booking status']=data['booking status'].replace({'Canceled':0,'Not_Canceled':1})

# %%
data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in ['type of meal','room type','market segment type']:
    data[i]=le.fit_transform(data[i])

# %%
data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space  room type  \
# 0                      5             0                  0          0
# 1                      3             3                  0          0
# 2                      3             0                  0          0
# 3                      2             0                  0          0
# 4                      2             3                  0          0
#
#    lead time  market segment type  repeated  P-C  P-not-C  average price  \
# 0        224                    3         0    0        0          88.00
# ...

# %%
def convert_datetime(date_str):
    try:
        return pd.to_datetime(date_str, errors='raise', format='%m/%d/%Y')
    except ValueError:
        return pd.to_datetime(date_str, errors='coerce', format='%Y-%m-%d')
data['date of reservation'] = data['date of reservation'].apply(convert_datetime)

# %%
data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space  room type  \
# 0                      5             0                  0          0
# 1                      3             3                  0          0
# 2                      3             0                  0          0
# 3                      2             0                  0          0
# 4                      2             3                  0          0
#
#    lead time  market segment type  repeated  P-C  P-not-C  average price  \
# 0        224                    3         0    0        0          88.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          36285 non-null  int64
#  1   number of children        36285 non-null  int64
#  2   number of weekend nights  36285 non-null  int64
#  3   number of week nights     36285 non-null  int64
#  4   type of meal              36285 non-null  int32
#  5   car parking space         36285 non-null  int64
#  6   room type                 36285 non-null  int32
#  7   lead time                 36285 non-null  int64
#  8   market segment type       36285 non-null  int32
#  9   repeated                  36285 non-null  int64
#  10  P-C                       36285 non-null  int64
#  11  P-not-C                   36285 non-null  int64
#  12  average price             36285 non-null  float64
#  13  special requests          36285 non-null  int64
# ...

# %%
data['reservation day']=data['date of reservation'].dt.day
data['reservation month']=data['date of reservation'].dt.month
data['reservation year']=data['date of reservation'].dt.year

# %%
data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space  room type  \
# 0                      5             0                  0          0
# 1                      3             3                  0          0
# 2                      3             0                  0          0
# 3                      2             0                  0          0
# 4                      2             3                  0          0
#
#    lead time  market segment type  repeated  P-C  P-not-C  average price  \
# 0        224                    3         0    0        0          88.00
# ...

# %%
data.drop('date of reservation',axis=1,inplace=True)

# %%
X=data.drop('booking status',axis=1)
y=data['booking status']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV,StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
per=data['booking status'].value_counts(normalize=True)

# %%
per
# Out:
# booking status
# 1    0.672344
# 0    0.327656
# Name: proportion, dtype: float64

# %%
def tuning(clf,parameter,X_train,y_train):
    cv=StratifiedKFold(n_splits=5,shuffle=True)
    cls_grid=GridSearchCV(clf,parameter,cv=cv,scoring='f1',n_jobs=-1)
    cls_grid.fit(X_train,y_train)
    best_hp=cls_grid.best_params_
    return cls_grid.best_estimator_,best_hp

# %%
dt=DecisionTreeClassifier()

# %%
dt_parameter_grid={'criterion':['gini','entropy'],
                  'max_depth':[12,13,14]}

# %%
tuning(dt,dt_parameter_grid,X_train,y_train)
# Out:
# (DecisionTreeClassifier(criterion='entropy', max_depth=13),
#  {'criterion': 'entropy', 'max_depth': 13})

# %%
dt=DecisionTreeClassifier(criterion='gini',max_depth= 12)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=12)

# %%
y_pred=dt.predict(X_test)

# %%
dtc_ac=accuracy_score(y_test,y_pred)

# %%
dtc_ac
# Out:
# 0.8841118919663773

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[1922,  457],
#        [ 384, 4494]], dtype=int64)

# %%
xgb=XGBClassifier()

# %%
xgb_paran_grid={'n_estimators':[250,300],'learning_rate':[0.01,0.001,0.1],'max_depth':[7,8]}

# %%
tuning(xgb,xgb_paran_grid,X_train,y_train)
# Out:
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.1, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=8, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=250, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 250})

# %%
xgb=XGBClassifier(learning_rate= 0.1, max_depth=8, n_estimators= 300)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(X_test)

# %%
xgb_ac=accuracy_score(y_test,y_pred)

# %%
xgb_ac
# Out:
# 0.9036792062835882

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[1953,  426],
#        [ 273, 4605]], dtype=int64)

# %%
model=pd.DataFrame({'Model':['Decision Tree Classifier','XGBClassifier'],
                   'Accuracy':[dtc_ac,xgb_ac]})

# %%
model
# Out:
#                       Model  Accuracy
# 0  Decision Tree Classifier  0.884112
# 1             XGBClassifier  0.903679
